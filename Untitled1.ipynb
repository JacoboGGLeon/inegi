# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = '../../Downloads/Ag.csv'

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    Wavelength(nm)       n       k
# 0          187.88  0.9950  1.1300
# 1          189.31  1.0043  1.1494
# 2          190.77  1.0120  1.1600
# 3          192.25  1.0195  1.1681
# 4          193.75  1.0280  1.1800

# %%
df.columns
# Out:
# Index(['Wavelength(nm)', 'n', 'k'], dtype='object')

# %%
plt.plot(df['Wavelength(nm)'], df['n'])
plt.xlabel('Wavelength(nm)')
plt.ylabel('n')
plt.savefig('ag_n.png')

# %%
plt.plot(df['Wavelength(nm)'], df['k'])
plt.xlabel('Wavelength(nm)')
plt.ylabel('k')
plt.savefig('ag_k.png')

# %%
from scipy.stats import truncnorm
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 1)

# %%
a, b = 0, 0.5
mean, var, skew, kurt = truncnorm.stats(a, b, moments='mvsk')
x = np.linspace(truncnorm.ppf(0.01, a, b), truncnorm.ppf(0.99, a, b), 100)
plt.plot(x, truncnorm.pdf(x, a, b), 'r-', lw=5, alpha=0.6, label='truncnorm pdf')

# %%
a, b = 0.5, 0.9
mean, var, skew, kurt = truncnorm.stats(a, b, moments='mvsk')
x = np.linspace(truncnorm.ppf(0.01, a, b), truncnorm.ppf(0.99, a, b), 100)
plt.plot(x, truncnorm.pdf(x, a, b), 'r-', lw=5, alpha=0.6, label='truncnorm pdf')

# %%
a, b = 0.9, 1
mean, var, skew, kurt = truncnorm.stats(a, b, moments='mvsk')
x = np.linspace(truncnorm.ppf(0.01, a, b), truncnorm.ppf(0.99, a, b), 100)
plt.plot(x, truncnorm.pdf(x, a, b), 'r-', lw=5, alpha=0.6, label='truncnorm pdf')

# %%
import math 
import numpy as np

# %%
a = 0 
b = 0.5

mu = (b+a)/2
std = np.sqrt(((b**2)+(a**2))/2)

# %%
mu
# Out:
# 0.25

# %%
std
# Out:
# 0.3535533905932738

# %%
from scipy.stats import truncnorm

def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    return truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)

# %%
a = 0
b = 0.5

mu_yes = (b+a)/2
std_yes = np.sqrt(((b**2)+(a**2))/2)
mu_yes, std_yes
# Out:
# (0.25, 0.3535533905932738)

# %%
a = 0.5
b = 0.9

mu_no = (b+a)/2
std_no = np.sqrt(((b**2)+(a**2))/2)
mu_no, std_no
# Out:
# (0.7, 0.7280109889280518)

# %%
a = 0.9
b = 1

mu_maybe = (b+a)/2
std_maybe = np.sqrt(((b**2)+(a**2))/2)
mu_maybe, std_maybe
# Out:
# (0.95, 0.9513148795220224)

# %%
X1 = get_truncated_normal(mean=mu_yes, sd=1, low=1, upp=10)
X2 = get_truncated_normal(mean=mu_no, sd=1, low=1, upp=10)
X3 = get_truncated_normal(mean=mu_maybe, sd=1, low=1, upp=10)

import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, sharex=True)
ax[0].hist(X1.rvs(10000), normed=True)
ax[1].hist(X2.rvs(10000), normed=True)
ax[2].hist(X3.rvs(10000), normed=True)
plt.show()
# Out:
# /Users/jacoboleon/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
X1 = get_truncated_normal(mean=2, sd=1, low=1, upp=10)
X2 = get_truncated_normal(mean=5.5, sd=1, low=1, upp=10)
X3 = get_truncated_normal(mean=8, sd=1, low=1, upp=10)

import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, sharex=True)
ax[0].hist(X1.rvs(10000), normed=True)
ax[1].hist(X2.rvs(10000), normed=True)
ax[2].hist(X3.rvs(10000), normed=True)
plt.show()
# Out:
# /Users/jacoboleon/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
